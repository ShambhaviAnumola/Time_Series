# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
date_range=pd.date_range(start='1/1/2024',end='1/31/2024',freq='D')
date_range
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10', '2024-01-11', '2024-01-12',
#                '2024-01-13', '2024-01-14', '2024-01-15', '2024-01-16',
#                '2024-01-17', '2024-01-18', '2024-01-19', '2024-01-20',
#                '2024-01-21', '2024-01-22', '2024-01-23', '2024-01-24',
#                '2024-01-25', '2024-01-26', '2024-01-27', '2024-01-28',
#                '2024-01-29', '2024-01-30', '2024-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
temp_data=np.random.normal(loc=10,scale=5,size=len(date_range))
temp_data
# Out:
# array([11.68313203, 13.75435009, 10.13901429,  2.58678426, 13.20579121,
#        -4.32693709,  6.64276749,  2.98653634, 13.3419343 , 20.51754414,
#         3.63727561,  6.69482419,  6.22505247, 10.14758563, 13.12360948,
#         8.97710936, 14.72601893,  9.38789137, 18.94782203,  8.75079524,
#        13.00866627,  5.21084758, 12.53482094, 11.84556649,  4.78049704,
#        10.02387035,  7.85633153,  3.03744023, 10.67035865, 13.2391404 ,
#        11.0045856 ])

# %%
temp_df=pd.DataFrame({'Date':date_range,'Temperature':temp_data})
temp_df
# Out:
#          Date  Temperature
# 0  2024-01-01    11.683132
# 1  2024-01-02    13.754350
# 2  2024-01-03    10.139014
# 3  2024-01-04     2.586784
# 4  2024-01-05    13.205791
# 5  2024-01-06    -4.326937
# 6  2024-01-07     6.642767
# 7  2024-01-08     2.986536
# 8  2024-01-09    13.341934
# 9  2024-01-10    20.517544
# 10 2024-01-11     3.637276
# 11 2024-01-12     6.694824
# 12 2024-01-13     6.225052
# 13 2024-01-14    10.147586
# 14 2024-01-15    13.123609
# 15 2024-01-16     8.977109
# 16 2024-01-17    14.726019
# 17 2024-01-18     9.387891
# 18 2024-01-19    18.947822
# 19 2024-01-20     8.750795
# 20 2024-01-21    13.008666
# 21 2024-01-22     5.210848
# 22 2024-01-23    12.534821
# 23 2024-01-24    11.845566
# 24 2024-01-25     4.780497
# 25 2024-01-26    10.023870
# 26 2024-01-27     7.856332
# 27 2024-01-28     3.037440
# 28 2024-01-29    10.670359
# 29 2024-01-30    13.239140
# 30 2024-01-31    11.004586

# %%
temp_df.head()
# Out:
#             Temperature
# Date
# 2024-01-01    11.683132
# 2024-01-02    13.754350
# 2024-01-03    10.139014
# 2024-01-04     2.586784
# 2024-01-05    13.205791

# %%
plt.figure(figsize=(8,3))
plt.plot(temp_df.index,temp_df['Temperature'])
plt.title('Daily temp in Jan24')
plt.xlabel('Date')
plt.ylabel('Temp in Celsius')
plt.show()

# %%
plt.figure(figsize=(8,3))
plt.scatter(temp_df.index,temp_df['Temperature'])
plt.title('Daily temp in Jan24')
plt.xlabel('Date')
plt.ylabel('Temp in Celsius')
plt.show()

# %%
plt.figure(figsize=(8,3))
pd.plotting.autocorrelation_plot(temp_df['Temperature'])
plt.title("Autocorrelation plot")
plt.show()

# %%
plt.figure(figsize=(8,3))
plt.hist(temp_df['Temperature'],bins=10)
plt.title(' Histogram for Daily temp in Jan24')
plt.xlabel('Temp in Celsius')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,3))
sns.kdeplot(temp_df['Temperature'],fill=True)
plt.title(' Density plot for Daily temp in Jan24')
plt.xlabel('Temp in Celsius')
plt.show()
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(8,3))
sns.boxplot(x=temp_df['Temperature'])
plt.title(' Box and Whisker plot for Daily temp in Jan24')
plt.xlabel('Temp in Celsius')
plt.show()

# %%
plt.figure(figsize=(8,3))
sns.heatmap(temp_df,cmap='coolwarm')
plt.title(' Heatmap for Daily temp in Jan24')
plt.xlabel('Temp in Celsius')
plt.show()
